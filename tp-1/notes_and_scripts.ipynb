# %% [markdown]
# <a href="https://colab.research.google.com/github/almemanuel/topicos-em-programacao-1/blob/main/notes_and_scripts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Anotações - 11/08

# %% [markdown]
# ## Introdução a Ciência de Dados

# %% [markdown]
# Ciência de dados é o processo de exploração, manipulação e análise de dados (utilizando o método científico) para responder determinadas questões e/ou fazer recomendações capazes de serem diferenciais em uma tomada de decisões.
#
# Este processo deve ter um forte embasamento matemático-estatístico ligado a uma determinada situação. Também deve ser escalável e replicável
#
# A ciência de dados está envolvida com machine learning
#
# ### Alguns conceito básicos
# - Dados são valores atribuídos a algo
# - Informações são os dados contextualizados para um determinado fim
# - Conhecimento é uma inferência a partir das informações
# - Inteligência é a tomada de decisões baseada no conhecimento
#
# A ciência de dados intersecciona matemática/estatística, negócios e tecnologia/automação
#
# A ciência de dados pode ser aplicada a tudo, desde que os dados sejam devidamente contextualizados
#
# O tamanho da base de dados pode tornar a análise inviável

# %% [markdown]
# # Anotações - 15/08

# %% [markdown]
# ## Introdução a Ciência de Dados - Continuação

# %% [markdown]
# O método científico pode ser resumido na observação e tentativa de chegar a algum resultado válido a respeito de um determinado fenomêno. Este método é aplicado na ciência de dados
#
# PS: dados que não serão utilizados devem ser excluídos, diminuindo, assim, a margem de erros

# %% [markdown]
# ## CRISP-DM (Cross Industry Standard Process for Data Mining)

# %% [markdown]
# Data Mining consiste em explorar um conjunto de dados de forma analítica a fim de encontrar um padrão
#
# CRISP-DM consiste em um conjunto de boas práticas (aka metodologia) para executar um projeto de Data Science criado em 1996. Consiste em:
# - Entendimento do negócio: definição do problema e alinhamento de expectativas
# - Entendimento dos dados
#     - Engenharia de dados: envolve tanto o _entendimento dos dados_ como a _preparação dos dados_
# - Preparação dos dados
# - Análise/Modelagem: análise exploratória, tratamento dos dados e definição do modelo
#     - Se necessário, retorna a fase de _entendimento dos dados_
# - Validação: processos que devem inferir se o modelo é funcional ou não
# - Preparação/Visualização: apresentação dos resultados obtidos
#
# Se o modelo for aplicado, é necessário realizar monitoramento, ajustes e melhorias contínuas

# %% [markdown]
# ## Introdução ao Python

# %% [markdown]
# Python é uma linguagem de programação simples e versátil, de grande popularidade no mercado

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# # Anotações - 18/08

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## NumPy
#  Biblioteca utilizada como base para o pandas. Usada para:
#  - computação numérica
#  - executar tarefas matemáticas
#
#  Muito utilizado para trabalhar com arrays, que possuem uma performance mais eficiente do que listas

# %%
vendas_valor = [150000, 230000, 820000, 143000, 184000]
comissao = [5, 8, 8, 5, 12]

# %%
venda_valor = np.array(vendas_valor)
comissao = np.array(comissao)

# %%
venda_valor * (comissao / 100)
# Out:
# array([ 7500., 18400., 65600.,  7150., 22080.])

# %%
venda_valor.shape
# Out:
# (5,)

# %%
venda_valor.dtype
# Out:
# dtype('int64')

# %%
data = np.array([1, 2, 3, 4.0])
print(data)
data.dtype
# Out:
# [1. 2. 3. 4.]
# dtype('float64')

# %% [markdown]
# # Anotações - 22/08

# %% [markdown]
# ## Matriz

# %%
dados_venda = np.array([[150000, 230000, 82000, 143000, 184000], [5, 8, 8, 5, 12]])

dados_venda
# Out:
# array([[150000, 230000,  82000, 143000, 184000],
#        [     5,      8,      8,      5,     12]])

# %%
dados_venda.shape
# Out:
# (2, 5)

# %%
dados_venda.dtype
# Out:
# dtype('int64')

# %%
dados_venda = np.array([['Lucas', 'Bia', 'Jean', 'Gabi', 'Pedro'], [150000, 230000, 82000, 143000, 184000]])
print(dados_venda)
# Out:
# [['Lucas' 'Bia' 'Jean' 'Gabi' 'Pedro']
#  ['150000' '230000' '82000' '143000' '184000']]

# %%
dados_venda.dtype
# Out:
# dtype('<U21')

# %% [markdown]
# ## Busca de elementos

# %%
dados_venda
# Out:
# array([['Lucas', 'Bia', 'Jean', 'Gabi', 'Pedro'],
#        ['150000', '230000', '82000', '143000', '184000']], dtype='<U21')

# %%
dados_venda[0]
# Out:
# array(['Lucas', 'Bia', 'Jean', 'Gabi', 'Pedro'], dtype='<U21')

# %%
dados_venda[0][1]
# Out:
# 'Bia'

# %% [markdown]
# ## Informações Estatísticas

# %%
dados_venda = np.array([[150000, 230000, 82000, 143000, 184000], [5, 8, 8, 5, 12]])

dados_venda
# Out:
# array([[150000, 230000,  82000, 143000, 184000],
#        [     5,      8,      8,      5,     12]])

# %%
np.mean(dados_venda[0])
# Out:
# 157800.0

# %%
np.median(dados_venda[0])
# Out:
# 150000.0

# %%
np.std(dados_venda[0])
# Out:
# 48836.05225650411

# %% [markdown]
# ## Pandas

# %% [markdown]
# ### Importar CSV

# %%
data = pd.read_csv('https://raw.githubusercontent.com/almemanuel/topicos-em-programacao-1/main/07.%20Pandas.csv')

data
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# 3                     Blood Father    Movie               NaN
# 4                     The Platform    Movie               Yes
# ...                            ...      ...               ...
# 7095           Worst Roommate Ever  TV Show               Yes
# 7096             Vikings: Valhalla  TV Show               Yes
# 7097                       Shooter    Movie               NaN
# 7098                       Shrek 2    Movie               NaN
# 7099                         Shrek    Movie               NaN
#
#      Netflix Release Date  Days In Top 10  Viewership Score
# 0            Mar 20, 2020               9                90
# 1            Jul 21, 2017               5                45
# 2            Mar 28, 2019               9                76
# 3            Mar 26, 2020               5                30
# 4            Mar 20, 2020               9                55
# ...                   ...             ...               ...
# 7095          Mar 1, 2022              10                81
# 7096         Feb 25, 2022              14               100
# 7097          Aug 1, 2014               3                 7
# 7098          Mar 1, 2022              10                33
# 7099          May 1, 2018               7                12
#
# [7100 rows x 10 columns]

# %% [markdown]
# ### Visualizar informações

# %%
data.head()
# Out:
#         As of  Rank Year to Date Rank Last Week Rank  \
# 0  2020-04-01     1                 1              1
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive  \
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score
# 0         Mar 20, 2020               9                90
# 1         Jul 21, 2017               5                45
# 2         Mar 28, 2019               9                76
# 3         Mar 26, 2020               5                30
# 4         Mar 20, 2020               9                55

# %%
data.tail()
# Out:
#            As of  Rank Year to Date Rank Last Week Rank                Title  \
# 7095  2022-03-11     6                 5              1  Worst Roommate Ever
# 7096  2022-03-11     7                 7              2    Vikings: Valhalla
# 7097  2022-03-11     8                 8              -              Shooter
# 7098  2022-03-11     9                 9              7              Shrek 2
# 7099  2022-03-11    10                10              -                Shrek
#
#          Type Netflix Exclusive Netflix Release Date  Days In Top 10  \
# 7095  TV Show               Yes          Mar 1, 2022              10
# 7096  TV Show               Yes         Feb 25, 2022              14
# 7097    Movie               NaN          Aug 1, 2014               3
# 7098    Movie               NaN          Mar 1, 2022              10
# 7099    Movie               NaN          May 1, 2018               7
#
#       Viewership Score
# 7095                81
# 7096               100
# 7097                 7
# 7098                33
# 7099                12

# %%
data.shape
# Out:
# (7100, 10)

# %%
display(data)
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# 3                     Blood Father    Movie               NaN
# 4                     The Platform    Movie               Yes
# ...                            ...      ...               ...
# 7095           Worst Roommate Ever  TV Show               Yes
# 7096             Vikings: Valhalla  TV Show               Yes
# 7097                       Shooter    Movie               NaN
# 7098                       Shrek 2    Movie               NaN
# 7099                         Shrek    Movie               NaN
#
#      Netflix Release Date  Days In Top 10  Viewership Score
# 0            Mar 20, 2020               9                90
# 1            Jul 21, 2017               5                45
# 2            Mar 28, 2019               9                76
# 3            Mar 26, 2020               5                30
# 4            Mar 20, 2020               9                55
# ...                   ...             ...               ...
# 7095          Mar 1, 2022              10                81
# 7096         Feb 25, 2022              14               100
# 7097          Aug 1, 2014               3                 7
# 7098          Mar 1, 2022              10                33
# 7099          May 1, 2018               7                12
#
# [7100 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   object
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   object
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 554.8+ KB

# %%
data.isnull().sum()
# Out:
# As of                      0
# Rank                       0
# Year to Date Rank          0
# Last Week Rank             0
# Title                      0
# Type                       0
# Netflix Exclusive       2501
# Netflix Release Date       0
# Days In Top 10             0
# Viewership Score           0
# dtype: int64

# %%
data.isnull()
# Out:
#       As of   Rank  Year to Date Rank  Last Week Rank  Title   Type  \
# 0     False  False              False           False  False  False
# 1     False  False              False           False  False  False
# 2     False  False              False           False  False  False
# 3     False  False              False           False  False  False
# 4     False  False              False           False  False  False
# ...     ...    ...                ...             ...    ...    ...
# 7095  False  False              False           False  False  False
# 7096  False  False              False           False  False  False
# 7097  False  False              False           False  False  False
# 7098  False  False              False           False  False  False
# 7099  False  False              False           False  False  False
#
#       Netflix Exclusive  Netflix Release Date  Days In Top 10  \
# 0                 False                 False           False
# 1                 False                 False           False
# 2                  True                 False           False
# 3                  True                 False           False
# 4                 False                 False           False
# ...                 ...                   ...             ...
# 7095              False                 False           False
# 7096              False                 False           False
# 7097               True                 False           False
# 7098               True                 False           False
# 7099               True                 False           False
#
#       Viewership Score
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 7095             False
# 7096             False
# 7097             False
# 7098             False
# 7099             False
#
# [7100 rows x 10 columns]

# %%
data.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Rank                  5.500000
# Days In Top 10       24.123662
# Viewership Score    122.790141
# dtype: float64

# %%
data.Title
# Out:
# 0       Tiger King: Murder, Mayhem …
# 1                              Ozark
# 2                       All American
# 3                       Blood Father
# 4                       The Platform
#                     ...
# 7095             Worst Roommate Ever
# 7096               Vikings: Valhalla
# 7097                         Shooter
# 7098                         Shrek 2
# 7099                           Shrek
# Name: Title, Length: 7100, dtype: object

# %%
data.Title.value_counts()
# Out:
# Cocomelon                       428
# Ozark                            85
# Cobra Kai                        81
# Manifest                         80
# The Queenâs Gambit             73
#                                ...
# The Office                        1
# Animals on the Loose: A You…      1
# Dark                              1
# The Secret Life of Pets 2         1
# Step Up Revolution                1
# Name: Title, Length: 645, dtype: int64

# %%
columns_list = ['Rank', 'Days In Top 10', 'Viewership Score']
select_data = data[columns_list]

# %%
select_data.mean()
# Out:
# Rank                  5.500000
# Days In Top 10       24.123662
# Viewership Score    122.790141
# dtype: float64

# %%
select_data.count()
# Out:
# Rank                7100
# Days In Top 10      7100
# Viewership Score    7100
# dtype: int64

# %%
select_data.median()
# Out:
# Rank                 5.5
# Days In Top 10       7.0
# Viewership Score    50.0
# dtype: float64

# %%
select_data.std()
# Out:
# Rank                  2.872484
# Days In Top 10       58.473789
# Viewership Score    213.861642
# dtype: float64

# %%
select_data.describe()
# Out:
#               Rank  Days In Top 10  Viewership Score
# count  7100.000000     7100.000000       7100.000000
# mean      5.500000       24.123662        122.790141
# std       2.872484       58.473789        213.861642
# min       1.000000        1.000000          1.000000
# 25%       3.000000        3.000000         19.000000
# 50%       5.500000        7.000000         50.000000
# 75%       8.000000       18.000000        128.000000
# max      10.000000      428.000000       1474.000000

# %% [markdown]
# ### Filtros

# %%
display(data)
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# 3                     Blood Father    Movie               NaN
# 4                     The Platform    Movie               Yes
# ...                            ...      ...               ...
# 7095           Worst Roommate Ever  TV Show               Yes
# 7096             Vikings: Valhalla  TV Show               Yes
# 7097                       Shooter    Movie               NaN
# 7098                       Shrek 2    Movie               NaN
# 7099                         Shrek    Movie               NaN
#
#      Netflix Release Date  Days In Top 10  Viewership Score
# 0            Mar 20, 2020               9                90
# 1            Jul 21, 2017               5                45
# 2            Mar 28, 2019               9                76
# 3            Mar 26, 2020               5                30
# 4            Mar 20, 2020               9                55
# ...                   ...             ...               ...
# 7095          Mar 1, 2022              10                81
# 7096         Feb 25, 2022              14               100
# 7097          Aug 1, 2014               3                 7
# 7098          Mar 1, 2022              10                33
# 7099          May 1, 2018               7                12
#
# [7100 rows x 10 columns]

# %%
data[data['Days In Top 10'] > 100]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank      Title     Type  \
# 2896  2021-01-15     7                 7             10  Cocomelon  TV Show
# 2909  2021-01-16    10                 7              9  Cocomelon  TV Show
# 2919  2021-01-17    10                10              9  Cocomelon  TV Show
# 3019  2021-01-27    10                 -              -  Cocomelon  TV Show
# 3029  2021-01-28    10                10              -  Cocomelon  TV Show
# ...          ...   ...               ...            ...        ...      ...
# 6674  2022-01-28     5                 6              -  Cocomelon  TV Show
# 6687  2022-01-29     8                 5              8  Cocomelon  TV Show
# 6718  2022-02-01     9                 -              7  Cocomelon  TV Show
# 6959  2022-02-25    10                 -              -  Cocomelon  TV Show
# 6998  2022-03-01     9                 -              -  Cocomelon  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 2896               NaN          Jun 1, 2020             101               291
# 2909               NaN          Jun 1, 2020             102               292
# 2919               NaN          Jun 1, 2020             103               293
# 3019               NaN          Jun 1, 2020             104               294
# 3029               NaN          Jun 1, 2020             105               295
# ...                ...                  ...             ...               ...
# 6674               NaN          Jun 1, 2020             424              1466
# 6687               NaN          Jun 1, 2020             425              1469
# 6718               NaN          Jun 1, 2020             426              1471
# 6959               NaN          Jun 1, 2020             427              1472
# 6998               NaN          Jun 1, 2020             428              1474
#
# [328 rows x 10 columns]

# %%
data[data.Title == 'Ozark']
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  Title     Type  \
# 1     2020-04-01     2                 2              -  Ozark  TV Show
# 11    2020-04-02     2                 2              -  Ozark  TV Show
# 21    2020-04-03     2                 2              -  Ozark  TV Show
# 31    2020-04-04     2                 2              2  Ozark  TV Show
# 41    2020-04-05     2                 2              2  Ozark  TV Show
# ...          ...   ...               ...            ...    ...      ...
# 6954  2022-02-25     5                 5              5  Ozark  TV Show
# 6967  2022-02-26     8                 5              8  Ozark  TV Show
# 6979  2022-02-27    10                 8              7  Ozark  TV Show
# 6986  2022-02-28     7                10              7  Ozark  TV Show
# 6996  2022-03-01     7                 7              8  Ozark  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 1                  Yes         Jul 21, 2017               5                45
# 11                 Yes         Jul 21, 2017               6                54
# 21                 Yes         Jul 21, 2017               7                63
# 31                 Yes         Jul 21, 2017               8                72
# 41                 Yes         Jul 21, 2017               9                81
# ...                ...                  ...             ...               ...
# 6954               Yes         Jul 21, 2017              85               524
# 6967               Yes         Jul 21, 2017              86               527
# 6979               Yes         Jul 21, 2017              87               528
# 6986               Yes         Jul 21, 2017              88               532
# 6996               Yes         Jul 21, 2017              89               536
#
# [85 rows x 10 columns]

# %%
data[(data.Title == 'Squid Game') & (data.Title != 'Cocomelon')]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank       Title     Type  \
# 5367  2021-09-19     8                 -              -  Squid Game  TV Show
# 5371  2021-09-20     2                 8              -  Squid Game  TV Show
# 5381  2021-09-21     2                 2              -  Squid Game  TV Show
# 5390  2021-09-22     1                 2              -  Squid Game  TV Show
# 5400  2021-09-23     1                 1              -  Squid Game  TV Show
# ...          ...   ...               ...            ...         ...      ...
# 5999  2021-11-21    10                 -              8  Squid Game  TV Show
# 6009  2021-11-22    10                10              8  Squid Game  TV Show
# 6049  2021-11-26    10                 -             10  Squid Game  TV Show
# 6059  2021-11-27    10                10              -  Squid Game  TV Show
# 6068  2021-11-28     9                10             10  Squid Game  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 5367               Yes         Sep 17, 2021               1                 3
# 5371               Yes         Sep 17, 2021               2                12
# 5381               Yes         Sep 17, 2021               3                21
# 5390               Yes         Sep 17, 2021               4                31
# 5400               Yes         Sep 17, 2021               5                41
# ...                ...                  ...             ...               ...
# 5999               Yes         Sep 17, 2021              62               490
# 6009               Yes         Sep 17, 2021              63               491
# 6049               Yes         Sep 17, 2021              64               492
# 6059               Yes         Sep 17, 2021              65               493
# 6068               Yes         Sep 17, 2021              66               495
#
# [66 rows x 10 columns]

# %%
data.loc[(data['Title'] == 'Squid Game') | (data.Title == 'Ozark'), ['As of', 'Title', 'Type']]
# Out:
#            As of  Title     Type
# 1     2020-04-01  Ozark  TV Show
# 11    2020-04-02  Ozark  TV Show
# 21    2020-04-03  Ozark  TV Show
# 31    2020-04-04  Ozark  TV Show
# 41    2020-04-05  Ozark  TV Show
# ...          ...    ...      ...
# 6954  2022-02-25  Ozark  TV Show
# 6967  2022-02-26  Ozark  TV Show
# 6979  2022-02-27  Ozark  TV Show
# 6986  2022-02-28  Ozark  TV Show
# 6996  2022-03-01  Ozark  TV Show
#
# [151 rows x 3 columns]

# %%
data.iloc[30:40]
# Out:
#          As of  Rank Year to Date Rank Last Week Rank  \
# 30  2020-04-04     1                 1              1
# 31  2020-04-04     2                 2              2
# 32  2020-04-04     3                 -              -
# 33  2020-04-04     4                 3              3
# 34  2020-04-04     5                 -              -
# 35  2020-04-04     6                 4              -
# 36  2020-04-04     7                 6              -
# 37  2020-04-04     8                 5              -
# 38  2020-04-04     9                 7              -
# 39  2020-04-04    10                 8              -
#
#                            Title     Type Netflix Exclusive  \
# 30  Tiger King: Murder, Mayhem …  TV Show               Yes
# 31                         Ozark  TV Show               Yes
# 32                   Money Heist  TV Show               Yes
# 33                  All American  TV Show               NaN
# 34               Coffee & Kareem    Movie               Yes
# 35     How to Fix a Drug Scandal  TV Show               Yes
# 36                  The Roommate    Movie               NaN
# 37                    Nailed It!  TV Show               Yes
# 38                    Unorthodox  TV Show               Yes
# 39              The Players Club    Movie               NaN
#
#    Netflix Release Date  Days In Top 10  Viewership Score
# 30         Mar 20, 2020              12               120
# 31         Jul 21, 2017               8                72
# 32         Dec 20, 2017               1                 8
# 33         Mar 28, 2019              12                99
# 34          Apr 3, 2020               1                 6
# 35          Apr 1, 2020               3                18
# 36          Apr 1, 2020               3                13
# 37          Mar 9, 2018               3                16
# 38         Mar 26, 2020               5                14
# 39          Apr 1, 2020               2                 4

# %%
data.iloc[30:40, [0, 4, 5]]
# Out:
#          As of                         Title     Type
# 30  2020-04-04  Tiger King: Murder, Mayhem …  TV Show
# 31  2020-04-04                         Ozark  TV Show
# 32  2020-04-04                   Money Heist  TV Show
# 33  2020-04-04                  All American  TV Show
# 34  2020-04-04               Coffee & Kareem    Movie
# 35  2020-04-04     How to Fix a Drug Scandal  TV Show
# 36  2020-04-04                  The Roommate    Movie
# 37  2020-04-04                    Nailed It!  TV Show
# 38  2020-04-04                    Unorthodox  TV Show
# 39  2020-04-04              The Players Club    Movie

# %% [markdown]
# ## Matplotlib

# %%
data['Days In Top 10'].plot.hist()

# %%
data.Title.value_counts().head(15).plot.bar()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
data['Viewership Score'].plot.kde()

# %% [markdown]
# # 22/09/2022

# %% [markdown]
# ## Boas Prática de Apresentação de Dados

# %% [markdown]
# - gráficos devem possuir apresentação clara e limpa
# - é importante que os gráficos iniciem com 0
# - eixos secundários podem causar confusão
# - a apresentação dos dados deve ser tranquila para o usuário
# - evitar elementos visuais que ocupem espaço mas não aumentem o entendimento
# - objetos fisicamente próximos são compreendidos como parte de um grupo
# - objetos parecidos são percebidos como relacionados
# - objetos fisicamento delimitados costumam ser parte de um grupo
# - quando partes de um todo faltam, a tendência é que o próprio cerébro complete a informação
# - o cérebro cria continuidade mesmo que ela não seja explícita
# - elementos conectados são tidos como parte de um grupo
# - o contraste deve ser usado estrategicamente para enfatizar algo
# - a visualização deve ser fácil de compreender
